# %% [markdown]
# # AutoML (askl) trained on every file individually, tested on the rest (4 cores, 30 seconds per file)
# AutoML's data preprocessing is applied to these tests. The model will be trained on file A, tested on files B,C,D.., then on B, tested on A,C,D.. etc

# %%
import sys
sys.path.append("../../")
from time import process_time
from os import listdir, chdir, environ

def warn(*args, **kwargs):
  pass
import warnings
warnings.warn = warn

if not sys.warnoptions:
    warnings.simplefilter("ignore")
    environ["PYTHONWARNINGS"] = "ignore"

from modules.NetworkTraffic import NT2
from sklearn import model_selection, metrics
from autosklearn.classification import AutoSklearnClassifier

FilesToTest = list()
chdir("../../data")
for file in listdir():
  if file.endswith(".csv"):
    FilesToTest.append(file)

TestSize = [0.4]
ModelsToTest = [AutoSklearnClassifier(time_left_for_this_task=300, memory_limit=4096, n_jobs=-1)]
OutputResults = dict()
#ModelResults = dict()

# %%
import pandas as pd
from copy import deepcopy
df_leader = None

def testMe():
  global df_leader
  df_leader = pd.DataFrame()
  OutputResults.clear()
  #ModelResults.clear()

  for index, file in enumerate(FilesToTest):
    print(file, end=', ')
    OutputResults[file] = dict()
    currentFileData = NT2(file, transform=False, drop=False)
    restOfFiles = deepcopy(FilesToTest)
    restOfFiles.pop(index)
    restOfTheFilesData = NT2(restOfFiles, transform=False, drop=False)

    for model in ModelsToTest:
      #print(f"{file} : {str(model)}", end=", ")
      model.fit(currentFileData.data, currentFileData.target)
      y_pred = model.predict(restOfTheFilesData.data)
      score = metrics.accuracy_score(restOfTheFilesData.target, y_pred)
      OutputResults[file].update({str(model): {"Accuracy": score}})
      try:
        OutputResults[file][str(model)]["Final Ensemble"] = str(model.show_models())
      except:
        pass
      try:
        if df_leader.empty: df_leader = model.leaderboard()
        else: df_leader = pd.concat([df_leader, model.leaderboard()], ignore_index=False)
      except: pass
      try:
        OutputResults[file][str(model)]["Sprint"] = str(model.sprint_statistics())
      except KeyError:
        pass

# %%
import json
from os import path

def writeMe():
  with open("EveryFileTransfer_Untuned_AllTestResults.json", "a") as f:
    f.write(json.dumps(OutputResults, indent=2))

  df_leader.to_csv("Leaderboard.csv", mode='a')

  with open("EveryFileTransfer_Untuned_ModelResults.csv", "a") as f3:
    if path.exists("EveryFileTransfer_Untuned_ModelResults.csv"): f3.write("File Trained On,Model,Accuracy,Runtime\n")
    for file in OutputResults:
      for model in OutputResults[file]:
        f3.write(f"{file},{model},{OutputResults[file][model]['Accuracy']}\n")

# %%
REPEATS = 2
for _ in range(0, REPEATS):
  print(f"\n------{_}------")
  testMe()
  writeMe()
# Out:
# ------0------
# b5000d100.csv, [WARNING] [2022-08-31 13:51:19,681:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:51:34,613:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:51:35,388:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:51:35,760:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:51:36,590:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:51:36,818:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:51:51,816:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:51:51,952:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:52:03,122:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:52:03,636:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:52:04,409:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:52:04,802:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:52:18,514:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:52:28,393:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:52:28,794:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:52:28,980:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:52:29,305:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:52:30,832:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:52:31,260:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:52:47,875:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:52:59,705:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:53:17,382:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:53:17,940:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:53:32,597:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:53:33,243:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:53:50,212:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:53:50,520:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:53:51,043:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:54:05,968:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:54:24,068:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# b5000d30.csv, [WARNING] [2022-08-31 13:57:10,369:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:57:34,533:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:57:46,587:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:57:59,376:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:58:10,621:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:58:21,961:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:58:32,473:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:58:32,787:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:58:35,476:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:58:47,802:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:58:52,562:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:59:02,888:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:59:19,622:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:59:19,899:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:59:34,548:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:59:34,722:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:59:34,904:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:59:35,241:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:59:50,074:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 13:59:50,306:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:00:09,379:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# b100d10.csv, b1000d10.csv, [WARNING] [2022-08-31 14:08:53,549:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:09:08,566:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:09:30,515:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:09:50,752:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:10:12,265:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:10:33,652:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:10:34,023:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:10:34,266:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:10:34,790:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:10:36,583:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:10:36,752:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:10:37,291:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:11:00,612:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:11:01,191:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:11:01,719:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:11:19,809:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:11:20,136:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:11:20,417:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:11:21,197:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:11:42,756:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:12:00,381:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# b1000d100.csv, [WARNING] [2022-08-31 14:14:31,031:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:14:44,788:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:14:45,783:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:14:59,997:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:15:20,108:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:15:33,202:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:15:33,623:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:15:46,821:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:15:58,128:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:15:59,691:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:16:13,635:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:16:25,823:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:16:40,543:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:16:52,682:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:17:07,273:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:17:19,472:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:17:39,815:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# b100d100.csv, [WARNING] [2022-08-31 14:20:01,812:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:20:16,159:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:20:32,537:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:20:56,209:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:21:11,864:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:21:12,157:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:21:12,850:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:21:33,234:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:21:52,383:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:21:52,744:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:21:52,938:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:22:05,253:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:22:29,192:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:22:52,471:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:23:12,862:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# b5000d10.csv, [WARNING] [2022-08-31 14:26:02,343:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:26:18,149:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:26:36,881:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:26:51,496:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:27:13,874:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:27:14,093:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:27:14,253:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:27:40,919:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:28:00,938:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:28:01,257:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:28:24,942:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:28:45,894:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:28:46,342:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:29:11,281:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# b1000d30.csv, [WARNING] [2022-08-31 14:31:58,662:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:32:20,000:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:32:31,410:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:32:48,098:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:32:48,310:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:32:48,587:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:33:12,240:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:33:30,083:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:33:41,969:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:33:42,238:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:34:02,490:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:34:28,945:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:34:29,302:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:34:29,626:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:34:29,895:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:34:31,759:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:35:06,416:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:35:07,002:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# b100d30.csv, [WARNING] [2022-08-31 14:38:01,325:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:38:20,538:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:38:37,092:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:38:58,605:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:39:19,780:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:39:20,144:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:39:20,403:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:39:21,807:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:39:21,948:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:39:40,739:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:39:57,800:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:39:58,181:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:39:58,516:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:40:00,334:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:40:00,656:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:40:01,631:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:40:01,986:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:40:23,474:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:40:51,948:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:40:52,314:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:40:52,695:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2022-08-31 14:41:09,147:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
#
# ------1------
# b5000d100.csv, [WARNING] [2022-08-31 14:43:51,707:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# Process ForkServerProcess-671:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nick/.local/lib/python3.8/site-packages/autosklearn/util/logging_.py", line 320, in start_log_server
#     receiver.serve_until_stopped()
#   File "/home/nick/.local/lib/python3.8/site-packages/autosklearn/util/logging_.py", line 350, in serve_until_stopped
#     rd, wr, ex = select.select([self.socket.fileno()],
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/nick/Documents/cs791/AutoML CV/Transfer - OneToMany - AutoML (askl) Processed/EveryFileTransfer_4core.ipynb Cell 5' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/nick/Documents/cs791/AutoML%20CV/Transfer%20-%20OneToMany%20-%20AutoML%20%28askl%29%20Processed/EveryFileTransfer_4core.ipynb#ch0000004?line=1'>2</a> for _ in range(0, REPEATS):
#       <a href='vscode-notebook-cell:/home/nick/Documents/cs791/AutoML%20CV/Transfer%20-%20OneToMany%20-%20AutoML%20%28askl%29%20Processed/EveryFileTransfer_4core.ipynb#ch0000004?line=2'>3</a>   print(f"\n------{_}------")
# ----> <a href='vscode-notebook-cell:/home/nick/Documents/cs791/AutoML%20CV/Transfer%20-%20OneToMany%20-%20AutoML%20%28askl%29%20Processed/EveryFileTransfer_4core.ipynb#ch0000004?line=3'>4</a>   testMe()
#       <a href='vscode-notebook-cell:/home/nick/Documents/cs791/AutoML%20CV/Transfer%20-%20OneToMany%20-%20AutoML%20%28askl%29%20Processed/EveryFileTransfer_4core.ipynb#ch0000004?line=4'>5</a>   writeMe()
#
# /home/nick/Documents/cs791/AutoML CV/Transfer - OneToMany - AutoML (askl) Processed/EveryFileTransfer_4core.ipynb Cell 3' in testMe()
#      <a href='vscode-notebook-cell:/home/nick/Documents/cs791/AutoML%20CV/Transfer%20-%20OneToMany%20-%20AutoML%20%28askl%29%20Processed/EveryFileTransfer_4core.ipynb#ch0000002?line=16'>17</a> restOfTheFilesData = NT2(restOfFiles, transform=False, drop=False)
#      <a href='vscode-notebook-cell:/home/nick/Documents/cs791/AutoML%20CV/Transfer%20-%20OneToMany%20-%20AutoML%20%28askl%29%20Processed/EveryFileTransfer_4core.ipynb#ch0000002?line=18'>19</a> for model in ModelsToTest:
#      <a href='vscode-notebook-cell:/home/nick/Documents/cs791/AutoML%20CV/Transfer%20-%20OneToMany%20-%20AutoML%20%28askl%29%20Processed/EveryFileTransfer_4core.ipynb#ch0000002?line=19'>20</a>   #print(f"{file} : {str(model)}", end=", ")
# ---> <a href='vscode-notebook-cell:/home/nick/Documents/cs791/AutoML%20CV/Transfer%20-%20OneToMany%20-%20AutoML%20%28askl%29%20Processed/EveryFileTransfer_4core.ipynb#ch0000002?line=20'>21</a>   model.fit(currentFileData.data, currentFileData.target)
#      <a href='vscode-notebook-cell:/home/nick/Documents/cs791/AutoML%20CV/Transfer%20-%20OneToMany%20-%20AutoML%20%28askl%29%20Processed/EveryFileTransfer_4core.ipynb#ch0000002?line=21'>22</a>   y_pred = model.predict(restOfTheFilesData.data)
#      <a href='vscode-notebook-cell:/home/nick/Documents/cs791/AutoML%20CV/Transfer%20-%20OneToMany%20-%20AutoML%20%28askl%29%20Processed/EveryFileTransfer_4core.ipynb#ch0000002?line=22'>23</a>   score = metrics.accuracy_score(restOfTheFilesData.target, y_pred)
#
# File ~/.local/lib/python3.8/site-packages/autosklearn/estimators.py:1045, in AutoSklearnClassifier.fit(self, X, y, X_test, y_test, feat_type, dataset_name)
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/estimators.py?line=1041'>1042</a> # remember target type for using in predict_proba later.
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/estimators.py?line=1042'>1043</a> self.target_type = target_type
# -> <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/estimators.py?line=1044'>1045</a> super().fit(
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/estimators.py?line=1045'>1046</a>     X=X,
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/estimators.py?line=1046'>1047</a>     y=y,
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/estimators.py?line=1047'>1048</a>     X_test=X_test,
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/estimators.py?line=1048'>1049</a>     y_test=y_test,
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/estimators.py?line=1049'>1050</a>     feat_type=feat_type,
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/estimators.py?line=1050'>1051</a>     dataset_name=dataset_name,
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/estimators.py?line=1051'>1052</a> )
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/estimators.py?line=1053'>1054</a> # After fit, a classifier is expected to define classes_
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/estimators.py?line=1054'>1055</a> # A list of class labels known to the classifier, mapping each label
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/estimators.py?line=1055'>1056</a> # to a numerical index used in the model representation our output.
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/estimators.py?line=1056'>1057</a> self.classes_ = self.automl_.InputValidator.target_validator.classes_
#
# File ~/.local/lib/python3.8/site-packages/autosklearn/estimators.py:375, in AutoSklearnEstimator.fit(self, **kwargs)
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/estimators.py?line=372'>373</a> if self.automl_ is None:
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/estimators.py?line=373'>374</a>     self.automl_ = self.build_automl()
# --> <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/estimators.py?line=374'>375</a> self.automl_.fit(load_models=self.load_models, **kwargs)
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/estimators.py?line=376'>377</a> return self
#
# File ~/.local/lib/python3.8/site-packages/autosklearn/automl.py:2056, in AutoMLClassifier.fit(self, X, y, X_test, y_test, feat_type, dataset_name, only_return_configuration_space, load_models)
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=2044'>2045</a> def fit(
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=2045'>2046</a>     self,
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=2046'>2047</a>     X: SUPPORTED_FEAT_TYPES,
#    (...)
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=2053'>2054</a>     load_models: bool = True,
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=2054'>2055</a> ):
# -> <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=2055'>2056</a>     return super().fit(
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=2056'>2057</a>         X, y,
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=2057'>2058</a>         X_test=X_test,
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=2058'>2059</a>         y_test=y_test,
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=2059'>2060</a>         feat_type=feat_type,
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=2060'>2061</a>         dataset_name=dataset_name,
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=2061'>2062</a>         only_return_configuration_space=only_return_configuration_space,
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=2062'>2063</a>         load_models=load_models,
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=2063'>2064</a>         is_classification=True,
#    <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=2064'>2065</a>     )
#
# File ~/.local/lib/python3.8/site-packages/autosklearn/automl.py:931, in AutoML.fit(self, X, y, task, X_test, y_test, feat_type, dataset_name, only_return_configuration_space, load_models, is_classification)
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=897'>898</a> _proc_smac = AutoMLSMBO(
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=898'>899</a>     config_space=self.configuration_space,
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=899'>900</a>     dataset_name=self._dataset_name,
#    (...)
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=925'>926</a>     trials_callback=self._get_trials_callback
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=926'>927</a> )
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=928'>929</a> try:
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=929'>930</a>     self.runhistory_, self.trajectory_, self._budget_type = \
# --> <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=930'>931</a>         _proc_smac.run_smbo()
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=931'>932</a>     trajectory_filename = os.path.join(
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=932'>933</a>         self._backend.get_smac_output_directory_for_run(self._seed),
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=933'>934</a>         'trajectory.json')
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=934'>935</a>     saveable_trajectory = \
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=935'>936</a>         [list(entry[:2]) + [entry[2].get_dictionary()] + list(entry[3:])
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/automl.py?line=936'>937</a>          for entry in self.trajectory_]
#
# File ~/.local/lib/python3.8/site-packages/autosklearn/smbo.py:498, in AutoMLSMBO.run_smbo(self)
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/smbo.py?line=494'>495</a> if self.trials_callback is not None:
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/smbo.py?line=495'>496</a>     smac.register_callback(self.trials_callback)
# --> <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/smbo.py?line=497'>498</a> smac.optimize()
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/smbo.py?line=499'>500</a> self.runhistory = smac.solver.runhistory
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/autosklearn/smbo.py?line=500'>501</a> self.trajectory = smac.solver.intensifier.traj_logger.trajectory
#
# File ~/.local/lib/python3.8/site-packages/smac/facade/smac_ac_facade.py:720, in SMAC4AC.optimize(self)
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/facade/smac_ac_facade.py?line=717'>718</a> incumbent = None
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/facade/smac_ac_facade.py?line=718'>719</a> try:
# --> <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/facade/smac_ac_facade.py?line=719'>720</a>     incumbent = self.solver.run()
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/facade/smac_ac_facade.py?line=720'>721</a> finally:
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/facade/smac_ac_facade.py?line=721'>722</a>     self.solver.save()
#
# File ~/.local/lib/python3.8/site-packages/smac/optimizer/smbo.py:229, in SMBO.run(self)
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/smbo.py?line=224'>225</a> start_time = time.time()
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/smbo.py?line=226'>227</a> # sample next configuration for intensification
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/smbo.py?line=227'>228</a> # Initial design runs are also included in the BO loop now.
# --> <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/smbo.py?line=228'>229</a> intent, run_info = self.intensifier.get_next_run(
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/smbo.py?line=229'>230</a>     challengers=self.initial_design_configs,
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/smbo.py?line=230'>231</a>     incumbent=self.incumbent,
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/smbo.py?line=231'>232</a>     chooser=self.epm_chooser,
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/smbo.py?line=232'>233</a>     run_history=self.runhistory,
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/smbo.py?line=233'>234</a>     repeat_configs=self.intensifier.repeat_configs,
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/smbo.py?line=234'>235</a>     num_workers=self.tae_runner.num_workers(),
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/smbo.py?line=235'>236</a> )
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/smbo.py?line=237'>238</a> # remove config from initial design challengers to not repeat it again
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/smbo.py?line=238'>239</a> self.initial_design_configs = [
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/smbo.py?line=239'>240</a>     c for c in self.initial_design_configs if c != run_info.config
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/smbo.py?line=240'>241</a> ]
#
# File ~/.local/lib/python3.8/site-packages/smac/intensification/simple_intensifier.py:169, in SimpleIntensifier.get_next_run(self, challengers, incumbent, chooser, run_history, repeat_configs, num_workers)
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/intensification/simple_intensifier.py?line=138'>139</a> """
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/intensification/simple_intensifier.py?line=139'>140</a> Selects which challenger to be used. As in a traditional BO loop,
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/intensification/simple_intensifier.py?line=140'>141</a> we sample from the EPM, which is the next configuration based on
#    (...)
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/intensification/simple_intensifier.py?line=165'>166</a>     evaluate a configuration
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/intensification/simple_intensifier.py?line=166'>167</a>  """
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/intensification/simple_intensifier.py?line=167'>168</a> # We always sample from the configs provided or the EPM
# --> <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/intensification/simple_intensifier.py?line=168'>169</a> challenger = self._next_challenger(challengers=challengers,
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/intensification/simple_intensifier.py?line=169'>170</a>                                    chooser=chooser,
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/intensification/simple_intensifier.py?line=170'>171</a>                                    run_history=run_history,
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/intensification/simple_intensifier.py?line=171'>172</a>                                    repeat_configs=repeat_configs)
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/intensification/simple_intensifier.py?line=173'>174</a> # Run tracker is a dictionary whose values indicate if a run has been
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/intensification/simple_intensifier.py?line=174'>175</a> # processed. If a value in this dict is false, it means that a worker
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/intensification/simple_intensifier.py?line=175'>176</a> # should still be processing this configuration.
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/intensification/simple_intensifier.py?line=176'>177</a> total_active_runs = len([v for v in self.run_tracker.values() if not v])
#
# File ~/.local/lib/python3.8/site-packages/smac/intensification/abstract_racer.py:260, in AbstractRacer._next_challenger(self, challengers, chooser, run_history, repeat_configs)
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/intensification/abstract_racer.py?line=257'>258</a> # select challenger from the generators
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/intensification/abstract_racer.py?line=258'>259</a> assert chall_gen is not None
# --> <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/intensification/abstract_racer.py?line=259'>260</a> for challenger in chall_gen:
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/intensification/abstract_racer.py?line=260'>261</a>     # repetitions allowed
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/intensification/abstract_racer.py?line=261'>262</a>     if repeat_configs:
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/intensification/abstract_racer.py?line=262'>263</a>         return challenger
#
# File ~/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py:723, in ChallengerList.__next__(self)
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=720'>721</a> else:
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=721'>722</a>     if self.challengers is None:
# --> <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=722'>723</a>         self.challengers = self.challengers_callback()
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=723'>724</a>     config = self.challengers[self._index]
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=724'>725</a>     self._index += 1
#
# File ~/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py:92, in AcquisitionFunctionMaximizer.maximize.<locals>.next_configs_by_acq_value()
#      <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=90'>91</a> def next_configs_by_acq_value() -> List[Configuration]:
# ---> <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=91'>92</a>     return [t[1] for t in self._maximize(runhistory, stats, num_points)]
#
# File ~/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py:656, in LocalAndSortedRandomSearch._maximize(self, runhistory, stats, num_points)
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=640'>641</a> def _maximize(
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=641'>642</a>     self,
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=642'>643</a>     runhistory: RunHistory,
#    (...)
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=646'>647</a>
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=647'>648</a>     # Get configurations sorted by EI
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=648'>649</a>     next_configs_by_random_search_sorted = self.random_search._maximize(
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=649'>650</a>         runhistory,
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=650'>651</a>         stats,
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=651'>652</a>         num_points,
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=652'>653</a>         _sorted=True,
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=653'>654</a>     )
# --> <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=655'>656</a>     next_configs_by_local_search = self.local_search._maximize(
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=656'>657</a>         runhistory, stats, self.n_sls_iterations, additional_start_points=next_configs_by_random_search_sorted,
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=657'>658</a>     )
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=659'>660</a>     # Having the configurations from random search, sorted by their
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=660'>661</a>     # acquisition function value is important for the first few iterations
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=661'>662</a>     # of SMAC. As long as the random forest predicts constant value, we
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=662'>663</a>     # want to use only random configurations. Having them at the begging of
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=663'>664</a>     # the list ensures this (even after adding the configurations by local
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=664'>665</a>     # search, and then sorting them)
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=665'>666</a>     next_configs_by_acq_value = (
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=666'>667</a>         next_configs_by_random_search_sorted + next_configs_by_local_search
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=667'>668</a>     )
#
# File ~/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py:233, in LocalSearch._maximize(self, runhistory, stats, num_points, additional_start_points)
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=211'>212</a> """Starts a local search from the given startpoint and quits
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=212'>213</a> if either the max number of steps is reached or no neighbor
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=213'>214</a> with an higher improvement was found.
#    (...)
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=228'>229</a> List
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=229'>230</a> """
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=231'>232</a> init_points = self._get_initial_points(num_points, runhistory, additional_start_points)
# --> <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=232'>233</a> configs_acq = self._do_search(init_points)
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=234'>235</a> # shuffle for random tie-break
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=235'>236</a> self.rng.shuffle(configs_acq)
#
# File ~/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py:367, in LocalSearch._do_search(self, start_points)
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=364'>365</a> for j in range(obtain_n[i]):
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=365'>366</a>     try:
# --> <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=366'>367</a>         n = next(neighborhood_iterator)
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=367'>368</a>         neighbors_generated[i] += 1
#     <a href='file:///home/nick/.local/lib/python3.8/site-packages/smac/optimizer/ei_optimization.py?line=368'>369</a>         neighbors_for_i.append(n)
#
# KeyboardInterrupt:
